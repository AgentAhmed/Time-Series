# %%
# Install Pandas Data Reader
# pip install pandas-datareader

# %%
import pandas_datareader as pdr 
import pandas as pd 
from datetime import datetime
import yfinance as yf

# %%
df_tesla = yf.download('TSLA')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
type(df_tesla)
# Out:
# pandas.core.frame.DataFrame

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
df_tesla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-06-18  186.559998  187.199997  182.369995  184.860001  184.860001
# 2024-06-20  184.679993  185.210007  179.660004  181.570007  181.570007
# 2024-06-21  182.300003  183.949997  180.690002  183.009995  183.009995
# 2024-06-24  184.970001  188.800003  182.550003  182.580002  182.580002
# 2024-06-25  184.399994  187.970001  182.009995  187.350006  187.350006
#
#               Volume
# Date
# 2024-06-18  68982300
# 2024-06-20  55893100
# 2024-06-21  63029500
# 2024-06-24  61992100
# 2024-06-25  62905700

# %%
df_tesla['High'].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and y limit

df_tesla['High'].plot(xlim=['2023-01-01','2024-06-01'],ylim=[0,900],figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
# apply coloring
df_tesla['High'].plot(xlim=['2023-01-01','2024-06-01'],ylim=[0,900],figsize=(12,6),ls='--',c='green')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2024-06-11', '2024-06-12', '2024-06-13', '2024-06-14',
#                '2024-06-17', '2024-06-18', '2024-06-20', '2024-06-21',
#                '2024-06-24', '2024-06-25'],
#               dtype='datetime64[ns]', name='Date', length=3521, freq=None)

# %%
index = df_tesla.loc['2023-01-01':'2024-06-01'].index
share_open = df_tesla.loc['2023-01-01':'2024-06-01']['Open']

# %%
share_open
# Out:
# Date
# 2023-01-03    118.470001
# 2023-01-04    109.110001
# 2023-01-05    110.510002
# 2023-01-06    103.000000
# 2023-01-09    118.959999
#                  ...
# 2024-05-24    174.839996
# 2024-05-28    176.399994
# 2024-05-29    174.190002
# 2024-05-30    178.580002
# 2024-05-31    178.500000
# Name: Open, Length: 355, dtype: float64

# %%
index
# Out:
# DatetimeIndex(['2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-17',
#                ...
#                '2024-05-17', '2024-05-20', '2024-05-21', '2024-05-22',
#                '2024-05-23', '2024-05-24', '2024-05-28', '2024-05-29',
#                '2024-05-30', '2024-05-31'],
#               dtype='datetime64[ns]', name='Date', length=355, freq=None)

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
figure,axis =plt.subplots()
plt.tight_layout()
# for preventing overlapping
figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
## Datetime Index

# %%
df_tesla = df_tesla.reset_index()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3521 entries, 0 to 3520
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3521 non-null   datetime64[ns]
#  1   Open       3521 non-null   float64
#  2   High       3521 non-null   float64
#  3   Low        3521 non-null   float64
#  4   Close      3521 non-null   float64
#  5   Adj Close  3521 non-null   float64
#  6   Volume     3521 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 192.7 KB

# %%
# if date is in object format then use
# pd.to_datetime(df_tesla['Date'])

# %%
df_tesla.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
# making date as index
df_tesla = df_tesla.set_index('Date',drop=True)

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
## datetime 
from datetime import datetime

# %%
datetime(2023,11,21)
# Out:
# datetime.datetime(2023, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 6, 26, 12, 25, 31, 343795)

# %%
def add_num(num1,num2):
    return num1+num2

# %%
# Example for datetime
# start_time = datetime.now()
# num1 =20
# num2 =30
# for i in [1,2,3,4,5]:
#     add_num(num1,num2)
# end_time = datetime.now()
# print(end_time - start_time)
# Out:
# 0:00:00

# %%
date = datetime(2024,6,26)

# %%
date
# Out:
# datetime.datetime(2024, 6, 26, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2024, 6, 26)

# %%
date.day
# Out:
# 26

# %%
date.weekday()
# Out:
# 2

# %%
date.year
# Out:
# 2024

# %%
date.month
# Out:
# 6

# %% [markdown]
# # Time Resampling

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
df_tesla.resample(rule='YE').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-31    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-31    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-31   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# ...

# %%
df_tesla.resample(rule='YE').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-31    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-31   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# ...

# %%
## year and frequency
df_tesla.resample(rule='YE').max()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
## quaterly start frequency

df_tesla.resample(rule='QS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01    1.719333    2.028000    1.553333    1.592667    1.592667
# 2010-07-01    1.666667    1.728000    1.408667    1.465333    1.465333
# 2010-10-01    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-01-01    1.906000    1.914000    1.870000    1.896667    1.896667
# 2011-04-01    2.006667    2.100000    1.970000    2.009333    2.009333
# 2011-07-01    1.992667    2.029333    1.934000    1.982000    1.982000
# 2011-10-01    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-01-01    2.546000    2.663333    2.474000    2.529333    2.529333
# 2012-04-01    2.488667    2.564667    2.444667    2.534000    2.534000
# 2012-07-01    2.333333    2.400000    2.260000    2.397333    2.397333
# 2012-10-01    2.350667    2.386667    2.330000    2.352000    2.352000
# 2013-01-01    2.630000    2.666667    2.609333    2.632000    2.632000
# ...

# %%
df_tesla.resample(rule='QS').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
## Business End frequency
df_tesla.resample(rule='BA').max()['High'].plot()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21008\407857562.py:2: FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
#   df_tesla.resample(rule='BA').max()['High'].plot()
# <Axes: xlabel='Date'>

# %%
df_tesla.resample(rule='BQS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01    1.719333    2.028000    1.553333    1.592667    1.592667
# 2010-07-01    1.666667    1.728000    1.408667    1.465333    1.465333
# 2010-10-01    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-01-03    1.906000    1.914000    1.870000    1.896667    1.896667
# 2011-04-01    2.006667    2.100000    1.970000    2.009333    2.009333
# 2011-07-01    1.992667    2.029333    1.934000    1.982000    1.982000
# 2011-10-03    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-01-02    2.546000    2.663333    2.474000    2.529333    2.529333
# 2012-04-02    2.488667    2.564667    2.444667    2.534000    2.534000
# 2012-07-02    2.333333    2.400000    2.260000    2.397333    2.397333
# 2012-10-01    2.350667    2.386667    2.330000    2.352000    2.352000
# 2013-01-01    2.630000    2.666667    2.609333    2.632000    2.632000
# ...

# %%
## plotting
df_tesla['Open'].resample(rule='BA').mean().plot(kind='bar')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21008\2709072815.py:2: FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
#   df_tesla['Open'].resample(rule='BA').mean().plot(kind='bar')
# <Axes: xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='ME').mean()
# Out:
# Date
# 2010-06-30      1.493000
# 2010-07-31      1.338222
# 2010-08-31      1.303030
# 2010-09-30      1.385270
# 2010-10-31      1.381556
#                  ...
# 2024-02-29    191.735999
# 2024-03-31    177.000002
# 2024-04-30    165.411364
# 2024-05-31    177.504091
# 2024-06-30    179.694375
# Freq: ME, Name: Open, Length: 169, dtype: float64

# %%
df_tesla['Open'].resample(rule='M').max().plot(kind='bar')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21008\3741133797.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_tesla['Open'].resample(rule='M').max().plot(kind='bar')
# <Axes: xlabel='Date'>

# %%
df_tesla['High'].head()
# Out:
# Date
# 2010-06-29    1.666667
# 2010-06-30    2.028000
# 2010-07-01    1.728000
# 2010-07-02    1.540000
# 2010-07-06    1.333333
# Name: High, dtype: float64

# %%
df_tesla['High'].rolling(10)
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
df_tesla['High'].rolling(10).mean()
# Out:
# Date
# 2010-06-29           NaN
# 2010-06-30           NaN
# 2010-07-01           NaN
# 2010-07-02           NaN
# 2010-07-06           NaN
#                  ...
# 2024-06-18    182.219000
# 2024-06-20    183.125002
# 2024-06-21    183.547002
# 2024-06-24    184.492001
# 2024-06-25    185.432001
# Name: High, Length: 3521, dtype: float64

# %%
df_tesla['High'].rolling(10).mean().head(20)
# Out:
# Date
# 2010-06-29         NaN
# 2010-06-30         NaN
# 2010-07-01         NaN
# 2010-07-02         NaN
# 2010-07-06         NaN
# 2010-07-07         NaN
# 2010-07-08         NaN
# 2010-07-09         NaN
# 2010-07-12         NaN
# 2010-07-13    1.421333
# 2010-07-14    1.389000
# 2010-07-15    1.329533
# 2010-07-16    1.298733
# 2010-07-19    1.293067
# 2010-07-20    1.305400
# 2010-07-21    1.333867
# 2010-07-22    1.358733
# 2010-07-23    1.383133
# 2010-07-26    1.406000
# 2010-07-27    1.422933
# Name: High, dtype: float64

# %%
df_tesla['Open:30 days rolling'] = df_tesla['Open'].rolling(30).mean()

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
#
#             Open:30 days rolling
# Date
# 2010-06-29                   NaN
# 2010-06-30                   NaN
# 2010-07-01                   NaN
# 2010-07-02                   NaN
# 2010-07-06                   NaN

# %%
df_tesla[['Open','Open:30 days rolling']].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
## Assignment 
1. # Read the Microsoft Data
2. # Get Maximum price of the share from 2019 to 2024
3. # Which is the date of the lowest price of the stock?
4. # Which is the date of the highest price of the stock?
# Out:
# 4.0
